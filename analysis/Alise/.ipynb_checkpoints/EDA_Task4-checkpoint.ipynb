# %%
#EDA should include
#Two column features
#Three visualizations

# %% [markdown]
# ## **EDA Milestone 2**

# %% [markdown]
# ### 1. Clean Spotify Dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
import sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from scripts import project_functions

df = project_functions.read_and_process('../../data/raw/spotify_datasheet/dataset-of-00s.csv')
df
# Out:
#       index                                     Track  \
# 0       613                                        #1
# 1      5669                        '03 Bonnie & Clyde
# 2      1700                 (B) The Decade Of Statues
# 3       717  (David Bowie I Love You) Since I Was Six
# 4       252                  (Do Not Feed The) Oyster
# ...     ...                                       ...
# 5867   4265                                      全力少年
# 5868   5316                                      天体観測
# 5869   1661                                     焼け野が原
# 5870   3041                                  薔薇と彼女の王子
# 5871   3478                                        迷彩
#
#                                Artist  Danceability  Energy  Key  Loudness  \
# 0                               Nelly         0.692   0.588    7    -6.086
# 1     Jay-Z Featuring Beyonce Knowles         0.759   0.675    9    -5.148
# 2           Between The Buried And Me         0.159   0.939    9    -6.044
# ...

# %% [markdown]
# ##### Gaining an understanding of my data:

# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns 

#Understanding my variables
df.shape
df.head()
df.columns
# Out:
# Index(['index', 'Track', 'Artist', 'Danceability', 'Energy', 'Key', 'Loudness',
#        'Mode', 'Valence', 'Tempo', 'Time Signature', 'Target'],
#       dtype='object')

# %%
df.nunique(axis=0)
df.describe().apply(lambda s: s.apply(lambda x: format(x, 'f')))
# Out:
#              index Danceability       Energy          Key     Loudness  \
# count  5872.000000  5872.000000  5872.000000  5872.000000  5872.000000
# mean   2935.500000     0.542931     0.694511     5.276396    -7.449258
# std    1695.244722     0.190003     0.237792     3.564153     5.102543
# min       0.000000     0.058800     0.000348     0.000000   -47.327000
# 25%    1467.750000     0.416000     0.567000     2.000000    -8.315000
# 50%    2935.500000     0.556000     0.744000     5.000000    -6.041500
# 75%    4403.250000     0.681000     0.885000     8.000000    -4.562500
# max    5871.000000     0.986000     0.999000    11.000000     1.137000
#
#               Mode      Valence        Tempo Time Signature       Target
# count  5872.000000  5872.000000  5872.000000    5872.000000  5872.000000
# mean      0.645095     0.482262   121.613018       3.913999     0.500000
# std       0.478525     0.254567    30.179885       0.404280     0.500043
# ...

# %% [markdown]
# ### 2. Research Questions

# %% [markdown]
# The research questions I would like to focus on:
#
#   1. Is there a relationship between the danceability and valence and the sucess of the song becoming a 'hit'?
#   2. Is there a relationship between the Time Signature and the sucess rate of a song becoming a 'hit'?

# %% [markdown]
# ### 3. Data Visualizations

# %%
plot= sns.countplot(y="Time Signature", data=df,hue="Target", order=df['Time Signature'].value_counts().index).set(title='Most Popular Time Signature', xlabel='Count')

# %%
scatter1 = sns.scatterplot(data=df, x="Tempo", y="Energy", hue="Target")

scatter1.set_title('Hit Predictor: Energy and Tempo')
# Out:
# Text(0.5, 1.0, 'Hit Predictor: Energy and Tempo')

# %%
scatter2 = sns.scatterplot(data=df, x="Danceability", y="Valence", hue="Target")

scatter2.set_title('Hit Predictor: Danceability and Valence')
# Out:
# Text(0.5, 1.0, 'Hit Predictor: Danceability and Valence')

# %% [markdown]
# ### 4. Understanding my data

# %% [markdown]
# An important thing to understand about the Spotify 2000s dataset is that the Target column is an indicator of weather the song is considered a 'Hit or a 'Flop'. Looking at the mean of the Target column it shows that 50% of the songs are 'Hits' and 50% our 'Flops'. The most frequenent time signature of songs is 4/4 time. However the time signature not reveal a relationship between the sucess rate of the song. The data also shows that there is no overall relationship of the songs tempo. Althought, the Energy of the song, which is preceptual measure of intensity and activity, shows that people favor an Energy between 4.0 and 8.0. This means that death metal and Bach preludes are less likely to become a 'hit'. Looking at the Danceability and the Valence (weather the song is precives as happy or sad) there is not a strong relationship as there is larger varience between the two parameters. However, there is a positive relationship that shows the more danceable the song is the more happy and cheerful the song will be. Most songs that have higher valence and danceability are classied as 'hits' shown in orange.
