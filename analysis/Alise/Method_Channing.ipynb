# %%
import pandas as pd
import numpy as np

spotify00s = pd.read_csv('../../data/raw/spotify_datasheet/dataset-of-00s.csv')

spotify00s.head()
# Out:
#                       track             artist  \
# 0                 Lucky Man  Montgomery Gentry
# 1            On The Hotline       Pretty Ricky
# 2        Clouds Of Dementia         Candlemass
# 3  Heavy Metal, Raise Hell!      Zwartketterij
# 4           I Got A Feelin'   Billy Currington
#
#                                     uri  danceability  energy  key  loudness  \
# 0  spotify:track:4GiXBCUF7H6YfNQsnBRIzl         0.578   0.471    4    -7.270
# 1  spotify:track:1zyqZONW985Cs4osz9wlsu         0.704   0.854   10    -5.477
# 2  spotify:track:6cHZf7RbxXCKwEkgAZT4mY         0.162   0.836    9    -3.009
# 3  spotify:track:2IjBPp2vMeX7LggzRN3iSX         0.188   0.994    4    -3.745
# 4  spotify:track:1tF370eYXUcWwkIvaq3IGz         0.630   0.764    2    -4.353
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1       0.0289      0.368000           0.00000     0.159    0.532
# ...

# %%
spotify00s.rename(columns={"track":"Track", "artist":"Artist", "danceability":"Danceability", "energy":"Energy", "key":"Key", "loudness":"Loudness", "mode":"Mode", "speechiness":"Speechiness", "acousticness":"Acousticness", "instrumentalness":"Instrumentalness", "liveness":"Liveness", "valence":"Valence", "tempo":"Tempo", "time_signature":"Time Signature", "target":"Target"})
# Out:
#                                                   Track  \
# 0                                             Lucky Man
# 1                                        On The Hotline
# 2                                    Clouds Of Dementia
# 3                              Heavy Metal, Raise Hell!
# 4                                       I Got A Feelin'
# ...                                                 ...
# 5867                                        Summer Rain
# 5868                                              And I
# 5869  Mass in B minor BWV 232, Missa: Duetto - Chris...
# 5870                                               Loog
# 5871                               What The World Needs
#
#                      Artist                                   uri  \
# 0         Montgomery Gentry  spotify:track:4GiXBCUF7H6YfNQsnBRIzl
# 1              Pretty Ricky  spotify:track:1zyqZONW985Cs4osz9wlsu
# 2                Candlemass  spotify:track:6cHZf7RbxXCKwEkgAZT4mY
# ...

# %%
spotify00s.drop(axis =1, columns={'chorus_hit','sections','duration_ms','speechiness','acousticness','instrumentalness','uri','liveness'})
# Out:
#                                                   track  \
# 0                                             Lucky Man
# 1                                        On The Hotline
# 2                                    Clouds Of Dementia
# 3                              Heavy Metal, Raise Hell!
# 4                                       I Got A Feelin'
# ...                                                 ...
# 5867                                        Summer Rain
# 5868                                              And I
# 5869  Mass in B minor BWV 232, Missa: Duetto - Chris...
# 5870                                               Loog
# 5871                               What The World Needs
#
#                      artist  danceability  energy  key  loudness  mode  \
# 0         Montgomery Gentry         0.578  0.4710    4    -7.270     1
# 1              Pretty Ricky         0.704  0.8540   10    -5.477     0
# 2                Candlemass         0.162  0.8360    9    -3.009     1
# ...

# %%
spotify00s.describe(include=[object]).T
# Out:
#        count unique                                   top freq
# track   5872   5619                               Breathe    5
# artist  5872   2920                            Toby Keith   27
# uri     5872   5855  spotify:track:3f3omU8n47Mqyab5nCaGyT    2

# %%
spotify00s.describe(exclude=[object]).T
# Out:
#                    count           mean            std           min  \
# danceability      5872.0       0.542931       0.190003      0.058800
# energy            5872.0       0.694511       0.237792      0.000348
# key               5872.0       5.276396       3.564153      0.000000
# loudness          5872.0      -7.449258       5.102543    -47.327000
# mode              5872.0       0.645095       0.478525      0.000000
# speechiness       5872.0       0.092360       0.094997      0.022400
# acousticness      5872.0       0.214374       0.296511      0.000000
# instrumentalness  5872.0       0.150917       0.301452      0.000000
# liveness          5872.0       0.196141       0.161965      0.019300
# valence           5872.0       0.482262       0.254567      0.000000
# tempo             5872.0     121.613018      30.179885     46.755000
# duration_ms       5872.0  258170.628236  139534.121208  15920.000000
# time_signature    5872.0       3.913999       0.404280      0.000000
# ...

# %%
spotify00s.dropna()
# Out:
#                                                   track  \
# 0                                             Lucky Man
# 1                                        On The Hotline
# 2                                    Clouds Of Dementia
# 3                              Heavy Metal, Raise Hell!
# 4                                       I Got A Feelin'
# ...                                                 ...
# 5867                                        Summer Rain
# 5868                                              And I
# 5869  Mass in B minor BWV 232, Missa: Duetto - Chris...
# 5870                                               Loog
# 5871                               What The World Needs
#
#                      artist                                   uri  \
# 0         Montgomery Gentry  spotify:track:4GiXBCUF7H6YfNQsnBRIzl
# 1              Pretty Ricky  spotify:track:1zyqZONW985Cs4osz9wlsu
# 2                Candlemass  spotify:track:6cHZf7RbxXCKwEkgAZT4mY
# ...
