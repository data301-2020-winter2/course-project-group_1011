# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
import sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from scripts import project_functions

df = project_functions.read_and_process('../../data/raw/spotify_datasheet/dataset-of-00s.csv')
# Out:
#                                          Track  \
# 613                                         #1
# 5669                        '03 Bonnie & Clyde
# 1700                 (B) The Decade Of Statues
# 717   (David Bowie I Love You) Since I Was Six
# 252                   (Do Not Feed The) Oyster
# ...                                        ...
# 4265                                      全力少年
# 5316                                      天体観測
# 1661                                     焼け野が原
# 3041                                  薔薇と彼女の王子
# 3478                                        迷彩
#
#                                Artist  Danceability  Energy  Key  Loudness  \
# 613                             Nelly         0.692   0.588    7    -6.086
# 5669  Jay-Z Featuring Beyonce Knowles         0.759   0.675    9    -5.148
# 1700        Between The Buried And Me         0.159   0.939    9    -6.044
# 717      The Brian Jonestown Massacre         0.201   0.647   10    -6.842
# 252                   Stephen Malkmus         0.451   0.498    2    -8.535
# ...                               ...           ...     ...  ...       ...
# 4265                    Sukima Switch         0.639   0.790    2    -4.156
# 5316                  BUMP OF CHICKEN         0.366   0.949    1    -3.552
# 1661                            Cocco         0.330   0.934    4    -3.702
# 3041                 Heartsrevolution         0.499   0.562    0    -9.957
# 3478                     Sheena Ringo         0.176   0.838    5    -3.938
#
#       Mode  Valence    Tempo  Time Signature  Target
# 613      1    0.450  180.027               4       1
# 5669     0    0.328   89.642               4       1
# 1700     1    0.190  188.078               4       0
# 717      1    0.320  115.609               4       0
# 252      1    0.266   87.373               4       0
# ...    ...      ...      ...             ...     ...
# 4265     1    0.733  133.948               4       0
# 5316     1    0.467  164.979               4       0
# 1661     1    0.357  159.781               4       0
# 3041     0    0.375  171.006               4       0
# 3478     0    0.487  199.282               4       0
#
# [5872 rows x 11 columns]
